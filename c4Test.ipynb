# %%
from zumi.zumi import Zumi
import time

zumi = Zumi()

def follow_line(threshold=190, speed=2):
    """
    Function for Zumi to follow a black line using IR sensors.
    
    Parameters:
    - threshold (int): The IR sensor threshold to detect the black line.
    - speed (int): Speed of Zumi while moving forward.
    """

    while True:
        ir_readings = zumi.get_all_IR_data()
        bottom_right = ir_readings[1]
        bottom_left = ir_readings[3]

       

        # 🔹 Step 1: If both sensors lose the line, recovery mode
        if bottom_right < threshold and bottom_left < threshold:
            zumi.stop()
            time.sleep(0.2)

            # Move back slightly and check IR sensors again
            zumi.reverse(speed=1, duration=0.5)
            ir_readings = zumi.get_all_IR_data()
            bottom_right = ir_readings[1]
            bottom_left = ir_readings[3]

            

            # If still no line, turn left 90° and check again
            if ir_readings[1] < threshold and ir_readings[3] < threshold:
                zumi.turn_left(90)
                time.sleep(0.3)

                # If still no line, assume a dead-end and turn 180°
                ir_readings = zumi.get_all_IR_data()
                if ir_readings[1] < threshold and ir_readings[3] < threshold:
                    zumi.turn_right(180)

        # 🔹 Step 2: Drive forward if centered on the line
        elif bottom_right > threshold and bottom_left > threshold:
            zumi.forward(speed)

        elif bottom_right > threshold and bottom_left < threshold:
            zumi.stop()
            zumi.turn_right(10)
        elif bottom_right < threshold and bottom_left > threshold:
            zumi.stop()
            zumi.turn_left(10)

# Run the function
follow_line()

# %%
from zumi.zumi import Zumi
from zumi.util.screen import Screen
import csv
import time
import os

zumi = Zumi()
screen = Screen()

start_time = time.time()
zumi.reset_gyro()
turns = 0
turn_detected = False

while True:
    ir_readings = zumi.get_all_IR_data()
    bottom_right = ir_readings[1]
    bottom_left = ir_readings[3]
    front_right = ir_readings[0]
    front_left = ir_readings[5]

    # Threshold for detecting black (190-200) vs grey (100-120)
    threshold = 150  # Adjust as needed

    if bottom_right < threshold and bottom_left < threshold:
        zumi.reverse(speed = 15, duration = 0.2)
        time.sleep(0.5)
        zumi.turn_right(45)
        ir_readings = zumi.get_all_IR_data()
        bottom_right = ir_readings[1]
        bottom_left = ir_readings[3]
        if bottom_right < threshold or bottom_left < threshold:
            zumi.signal_left_on()
            zumi.turn_left(90)
            time.sleep(0.3)
            zumi.signal_left_off()
        else:
            zumi.signal_right_on()
            zumi.signal_right_off()

    elif bottom_right > threshold and bottom_left > threshold:
        zumi.control_motors(5,18)
        if not turn_detected and (zumi.read_z_angle() > 40 or zumi.read_z_angle() < -40):
            print(turns, zumi.read_z_angle())
            zumi.reset_gyro()
            turns += 1
            turn_detected = True

    elif bottom_right < threshold:
        # Both sensors detect black → Go straight
        zumi.control_motors(20,0)
    
    elif bottom_left < threshold:
        # Left sensor on black, right on grey → Slight left turn
        zumi.control_motors(0,20)  # Left wheel slower

    if -40 < zumi.read_z_angle() < 40:
        turn_detected = False

    if front_right < 15 and front_left < 15:
        zumi.stop()
        break
        
# Record end time
end_time = time.time()

# Open and write to the CSV file
csv_filename = "/home/pi/Dashboard/user/RobotChallenge/My_Projects/Jupyter/zumi_runtime.csv"

with open(csv_filename, mode='a', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow([start_time, end_time, turns])
# Out:
# Starting Zumi
# Pi Zero I2C is available
# Verified Pi Zero is the same
# Gyroscope previously calibrated
# Zumi board detected
# Compass detected
# OLED Screen detected
# Gyroscope & Accelerometer detected
# Zumi battery level  54 %
# 0 -54.045
# 1 -85.251
# 2 -47.143
# 3 117.917
# 4 -87.183
# 5 -48.44
# 6 -42.181
# 7 -52.527
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-1eeee484f809> in <module>
#      55         zumi.control_motors(0,20)  # Left wheel slower
#      56
# ---> 57     if -40 < zumi.read_z_angle() < 40:
#      58         turn_detected = False
#      59
#
# /usr/local/lib/python3.5/dist-packages/zumi/zumi.py in read_z_angle(self)
#    1168         """
#    1169         # updates and reads only the  Z angle
# -> 1170         angle_list = self.update_angles()
#    1171         z_angle = angle_list[2]
#    1172         z_angle = round(z_angle, 3)
#
# /usr/local/lib/python3.5/dist-packages/zumi/zumi.py in update_angles(self)
#    1087         # update all the mpu readings
#    1088         self.mpu_list = self.mpu.read_all_MPU_data()
# -> 1089         self.mpu_list.append(self.mpu.get_temp())
#    1090         time_now = time.time()
#    1091         dt = (time_now - self.gyro_time_past)
#
# /usr/local/lib/python3.5/dist-packages/zumi/zumi.py in get_temp(self)
#     502         """
#     503         TEMP_OUT0 = 0x41
# --> 504         raw_temp = self.__read_raw_MPU_data(TEMP_OUT0)
#     505         # convert to celsius
#     506         actual_temp = (raw_temp / 340) + 36.53
#
# /usr/local/lib/python3.5/dist-packages/zumi/zumi.py in __read_raw_MPU_data(self, addr)
#     524         """
#     525         try:
# --> 526             high = self.bus.read_byte_data(Device.MPU, addr)
#     527             low = self.bus.read_byte_data(Device.MPU, addr + 1)
#     528             value = ((high << 8) | low)
#
# /usr/local/lib/python3.5/dist-packages/smbus2/smbus2.py in read_byte_data(self, i2c_addr, register, force)
#     410             read_write=I2C_SMBUS_READ, command=register, size=I2C_SMBUS_BYTE_DATA
#     411         )
# --> 412         ioctl(self.fd, I2C_SMBUS, msg)
#     413         return msg.data.contents.byte
#     414
#
# KeyboardInterrupt:

# %%
zumi.stop()
